# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
wh_wine_df = pd.read_csv('F:\\DataScience\\Datasets\\winequality_white.csv', sep = ';')
wh_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wh_wine_df.shape
# Out:
# (4898, 12)

# %%
wh_wine_df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
wh_wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wh_wine_df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
wh_wine_df.quality.value_counts().sort_index()
# Out:
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# Name: quality, dtype: int64

# %%
sns.countplot(x = 'quality', data = wh_wine_df)

# %%
sns.set()
wh_wine_df.hist(figsize = (10,10), color = 'Red')
plt.show()

# %%
correlation_var = wh_wine_df.corr()
plt.figure(figsize = (12,6))
sns.heatmap(correlation_var, annot = True, linewidths = 0, vmin = -1, cmap = 'RdBu_r')

# %%
correlation_var['quality'].sort_values(ascending = False)
# Out:
# quality                 1.000000
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64

# %%
bx = sns.boxplot(x = 'quality', y = 'alcohol', data = wh_wine_df)
bx.set(xlabel = 'Wine Quality', ylabel = 'Alcohol Percent', title = 'Alcohol content in white wines of different quality')
# Out:
# [Text(0, 0.5, 'Alcohol Percent'),
#  Text(0.5, 0, 'Wine Quality'),
#  Text(0.5, 1.0, 'Alcohol content in white wines of different quality')]

# %%
sns.regplot(x = 'residual sugar', y = 'density', data = wh_wine_df)

# %%
sns.regplot(x = 'quality', y = 'density', data = wh_wine_df)

# %%
sns.regplot(x = 'alcohol', y = 'density', data = wh_wine_df)
